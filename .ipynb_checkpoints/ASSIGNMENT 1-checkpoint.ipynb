# %% [markdown]
# # QUESTION 1

# %%
a = 15
b = 4

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
# Out:
# Sum: 19
# Difference: 11
# Product: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3

# %% [markdown]
# # QUESTION 2

# %%
favorite_food = "Chinese"

print("My favorite food is:", favorite_food)
# Out:
# My favorite food is: Chinese

# %% [markdown]
# # QUESTION 3

# %%
apple = '22'    
mangoes = 33    

total = int(apple) + mangoes   

print("I have", total, "fruits.")
# Out:
# I have 55 fruits.

# %% [markdown]
# # QUESTON 4

# %%
num1 = 10
num2 = 5.6
num3 = 4.43
num4 = '23'

# Conversions
print("Conversions:")

# Integer to Float
print("Integer to Float:", float(num1))

# Float to Integer
print("Float to Integer:", int(num2))

# Float to String
print("Float to String:", str(num3))

# String to Integer
print("String to Integer:", int(num4))
# Out:
# Conversions:
# Integer to Float: 10.0
# Float to Integer: 5
# Float to String: 4.43
# String to Integer: 23

# %% [markdown]
# # QUESTION 5

# %%
name = "AYESHA"
age = 27

age = age + 1

print("Name:", name)
print("Final Age:", age)
# Out:
# Name: AYESHA
# Final Age: 28

# %% [markdown]
# # QUESTION 6

# %%
a = 2
b = 1
c = 6
d = 3

print("Add a and b:            ", a + b)
print("Subtract c and a:       ", c - a)
print("Multiply d and b:       ", d * b)
print("Divide c and d:         ", c / d)
print("Modulus of c divided d: ", c % d)
print("Square of (d+a):        ", (d + a) ** 2)
# Out:
# Add a and b:             3
# Subtract c and a:        4
# Multiply d and b:        3
# Divide c and d:          2.0
# Modulus of c divided d:  0
# Square of (d+a):         25

# %% [markdown]
# # QUESTION 7

# %%
age = 20

age += 5

print("age now:", age)
# Out:
# age now: 25

# %% [markdown]
# # QUESTION 8

# %%
a = '2'
b = '11'
c = 6.3

print("Convert a to integer then add to c:      ", int(a) + c)
print("Convert b to float then multiply by c:   ", float(b) * c)
print("Convert c to integer then add to c:      ", int(c) + c)
# Out:
# Convert a to integer then add to c:       8.3
# Convert b to float then multiply by c:    69.3
# Convert c to integer then add to c:       12.3

# %% [markdown]
# # QUESTION 9

# %%
books = 12

books -= 4

print("Books remaining:", books)
# Out:
# Books remaining: 8

# %% [markdown]
# # QUESTION 10

# %%
cookies = 5

cookies *= 3

print("Cookies baked today:", cookies)
# Out:
# Cookies baked today: 15

# %% [markdown]
# # QUESTION 11

# %%
Problem = 20 - 4 * (3 + 2) + 18 / 3

print("Result:", Problem)
# Out:
# Result: 6.0
