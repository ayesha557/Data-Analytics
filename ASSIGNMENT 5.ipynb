# %% [markdown]
# # QUESTION 1

# %%
age = int(input("Enter your age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20 and age <= 64:
    print("Adult")
elif age >= 65:
    print("Senior")
else:
    print("Invalid age")
# Out:
# Enter your age:  28
# Adult

# %% [markdown]
# # QUESTION 2

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("Largest number is:", num1)
elif num2 >= num1 and num2 >= num3:
    print("Largest number is:", num2)
else:
    print("Largest number is:", num3)

if num1 == num2 == num3:
    print("All three numbers are equal.")
elif num1 == num2 or num1 == num3 or num2 == num3:
    print("Two numbers are equal.")
else:
    print("All numbers are different.")
# Out:
# Enter first number:  5
# Enter second number:  8
# Enter third number:  9
# Largest number is: 9
# All numbers are different.

# %% [markdown]
# # QUESTION 3

# %%
my_tuple = (5, 10, 15, 20, 25)

num = int(input("Enter an integer: "))

if num in my_tuple:
    print(num, "exists in the tuple.")
else:
    print(num, "does not exist in the tuple.")
# Out:
# Enter an integer:  11
# 11 does not exist in the tuple.

# %% [markdown]
# # QUESTION 4

# %%
title = input("Enter book title: ")
author = input("Enter author name: ")
year = int(input("Enter year of publication: "))
price = float(input("Enter price of the book: "))

book = (title, author, year, price)

print("\nBook Details")
print("Title:", book[0])
print("Author:", book[1])
print("Year of Publication:", book[2])
print("Price: Rs", book[3])
# Out:
# Enter book title:  The Success Principles
# Enter author name:  Jack Canfield
# Enter year of publication:  2005
# Enter price of the book:  1500
# Book Details
# Title: The Success Principles
# Author: Jack Canfield
# Year of Publication: 2005
# Price: Rs 1500.0

# %% [markdown]
# # QUESTION 5

# %%
subjects = ["Math", "Science", "English", "Art", "Computer"]

subject = input("Enter the subject you are interested in: ")

if subject in subjects:
    print(subject, "is available.")
else:
    print(subject, "is not available.")
# Out:
# Enter the subject you are interested in:  Math
# Math is available.

# %% [markdown]
# # QUESTION 6

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# Enter a number:  0
# The number is Zero

# %% [markdown]
# # QUESTION 7

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "admin@123":
    print("Login Successful")
elif username != "admin" and password == "admin@123":
    print("Invalid Username")
elif username == "admin" and password != "admin@123":
    print("Invalid Password")
else:
    print("Invalid Username and Password")
# Out:
# Enter username:  admin
# Enter password:  12345
# Invalid Password

# %% [markdown]
# # QUESTION 8

# %%
age = int(input("Enter your age: "))
credit = int(input("Enter your credit score: "))
income = float(input("Enter your annual income: "))

if age < 18:
    print("You are not eligible for the loan due to age.")
elif credit < 650:
    print("You are not eligible for the loan due to low credit score.")
elif credit >= 700 and income >= 25000:
    print("You are eligible for the loan!")
elif credit >= 650 and income >= 30000:
    print("You are eligible for the loan!")
else:
    print("You are not eligible for the loan due to insufficient income.")
# Out:
# Enter your age:  28
# Enter your credit score:  720
# Enter your annual income:  400000
# You are eligible for the loan!

# %% [markdown]
# # QUESTION 9

# %%
letter = input("Enter a single letter: ")

if len(letter) == 1:
    if letter in "aeiouAEIOU":
        print(letter, "is a Vowel")
    elif letter.isalpha():
        print(letter, "is a Consonant")
    else:
        print("Please enter valid alphabet")
else:
    print("Please enter valid alphabet")
# Out:
# Enter a single letter:  k
# k is a Consonant
